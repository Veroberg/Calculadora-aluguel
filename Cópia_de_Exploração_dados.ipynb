# %% [markdown]
# <a href="https://colab.research.google.com/github/Veroberg/Calculadora-aluguel/blob/main/C%C3%B3pia_de_Explora%C3%A7%C3%A3o_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importando as linguagens necessárias para trabalhar na raspagem de dados do site Viva Real, de imóveis alugados

import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
# Puxando e filtrando as páginas que solicitei

paginas = ['']
for i in range(1,50):
    a = '?pagina='+str(i)
    print(a)
    paginas.append(a)
# Out:
# ?pagina=1
# ?pagina=2
# ?pagina=3
# ?pagina=4
# ?pagina=5
# ?pagina=6
# ?pagina=7
# ?pagina=8
# ?pagina=9
# ?pagina=10
# ?pagina=11
# ?pagina=12
# ?pagina=13
# ?pagina=14
# ?pagina=15
# ?pagina=16
# ?pagina=17
# ?pagina=18
# ?pagina=19
# ?pagina=20
# ?pagina=21
# ?pagina=22
# ?pagina=23
# ?pagina=24
# ?pagina=25
# ?pagina=26
# ?pagina=27
# ?pagina=28
# ?pagina=29
# ?pagina=30
# ?pagina=31
# ?pagina=32
# ?pagina=33
# ?pagina=34
# ?pagina=35
# ?pagina=36
# ?pagina=37
# ?pagina=38
# ?pagina=39
# ?pagina=40
# ?pagina=41
# ?pagina=42
# ?pagina=43
# ?pagina=44
# ?pagina=45
# ?pagina=46
# ?pagina=47
# ?pagina=48
# ?pagina=49

# %%
# Um print das páginas soclicitadas acima

paginas
# Out:
# ['',
#  '?pagina=1',
#  '?pagina=2',
#  '?pagina=3',
#  '?pagina=4',
#  '?pagina=5',
#  '?pagina=6',
#  '?pagina=7',
#  '?pagina=8',
#  '?pagina=9',
#  '?pagina=10',
#  '?pagina=11',
#  '?pagina=12',
#  '?pagina=13',
#  '?pagina=14',
#  '?pagina=15',
#  '?pagina=16',
#  '?pagina=17',
#  '?pagina=18',
#  '?pagina=19',
#  '?pagina=20',
#  '?pagina=21',
#  '?pagina=22',
#  '?pagina=23',
#  '?pagina=24',
#  '?pagina=25',
#  '?pagina=26',
#  '?pagina=27',
#  '?pagina=28',
#  '?pagina=29',
#  '?pagina=30',
#  '?pagina=31',
#  '?pagina=32',
#  '?pagina=33',
#  '?pagina=34',
#  '?pagina=35',
#  '?pagina=36',
#  '?pagina=37',
#  '?pagina=38',
#  '?pagina=39',
#  '?pagina=40',
#  '?pagina=41',
#  '?pagina=42',
#  '?pagina=43',
#  '?pagina=44',
#  '?pagina=45',
#  '?pagina=46',
#  '?pagina=47',
#  '?pagina=48',
#  '?pagina=49']

# %%
# Convertendo dados das colunas em Data Frame

import pandas as pd
def converter_df(aluguel_lista,quartos_lista,endereco_lista,banheiro_lista,vaga_lista,area_lista):
    data = {'aluguel':aluguel_lista,
           'quartos':quartos_lista,
           'endereco':endereco_lista,
           'banheiro':banheiro_lista,
            'vaga':vaga_lista,
            'area':area_lista}
    df = pd.DataFrame(data)
    return df

# %%
# Processo da trasnformação acima como listas

def scrap(url):
    c = requests.get(url).content
    soup = BeautifulSoup(c)
    
    # Lista de aluguel

    aluguel_tag = soup.find_all('div', {'class':'property-card__price js-property-card-prices js-property-card__price-small'}) 
    aluguel_lista = [p.text for p in aluguel_tag] 
     
    # Lista de quartos

    quartos_tag = soup.find_all('li', {'class': 'property-card__detail-item property-card__detail-room js-property-detail-rooms'}) 
    quartos_lista = [en.text for en in quartos_tag] 
   
    # Lista de endereço

    endereco_tag = soup.find_all('span', {'class': 'property-card__address'}) 
    endereco_lista = [fg.text for fg in endereco_tag] 
    
    # Lista de banheiro

    banheiro_tag = soup.find_all('li', {'class': 'property-card__detail-item property-card__detail-bathroom js-property-detail-bathroom'}) 
    banheiro_lista = [yp.text for yp in banheiro_tag] 
  

    vaga_tag = soup.find_all('li', {'class': 'property-card__detail-item property-card__detail-garage js-property-detail-garages'}) 
    vaga_lista = [yp.text for yp in vaga_tag] 

    area_tag = soup.find_all('li', {'class': 'property-card__detail-item property-card__detail-area'}) 
    area_lista = [yp.text for yp in area_tag] 


   # Listas transfromadas em df

    df=converter_df(aluguel_lista,quartos_lista,endereco_lista,banheiro_lista,vaga_lista,area_lista)
    
    return df

# %%
# Print das páginas solicitadas acima

paginas
# Out:
# ['',
#  '?pagina=1',
#  '?pagina=2',
#  '?pagina=3',
#  '?pagina=4',
#  '?pagina=5',
#  '?pagina=6',
#  '?pagina=7',
#  '?pagina=8',
#  '?pagina=9',
#  '?pagina=10',
#  '?pagina=11',
#  '?pagina=12',
#  '?pagina=13',
#  '?pagina=14',
#  '?pagina=15',
#  '?pagina=16',
#  '?pagina=17',
#  '?pagina=18',
#  '?pagina=19',
#  '?pagina=20',
#  '?pagina=21',
#  '?pagina=22',
#  '?pagina=23',
#  '?pagina=24',
#  '?pagina=25',
#  '?pagina=26',
#  '?pagina=27',
#  '?pagina=28',
#  '?pagina=29',
#  '?pagina=30',
#  '?pagina=31',
#  '?pagina=32',
#  '?pagina=33',
#  '?pagina=34',
#  '?pagina=35',
#  '?pagina=36',
#  '?pagina=37',
#  '?pagina=38',
#  '?pagina=39',
#  '?pagina=40',
#  '?pagina=41',
#  '?pagina=42',
#  '?pagina=43',
#  '?pagina=44',
#  '?pagina=45',
#  '?pagina=46',
#  '?pagina=47',
#  '?pagina=48',
#  '?pagina=49']

# %%
# Coletando dados de imóveis do site Viva Real

df_lista = []
for pg in paginas:
    URL = 'https://www.vivareal.com.br/aluguel/sp/sao-paulo/?pagina=7'.format(pg)
    print('Coletando URL:', URL)
    #try:
    df = scrap(URL)
    #print(df)
    #print('Coletando URL:', URL)
    #except Exception as e:
    #    print('Erro ao coletar dados na url:', url)
    #    print(e)
    df_lista.append(df)
    
# df_final = pd.concat(df_lista)
# Out:
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/?pagina=7
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/?pagina=7
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/?pagina=7
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/?pagina=7
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/?pagina=7
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/?pagina=7
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/?pagina=7
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/?pagina=7
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/?pagina=7
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/?pagina=7
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/?pagina=7
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/?pagina=7
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/?pagina=7
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/?pagina=7
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/?pagina=7
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/?pagina=7
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/?pagina=7
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/?pagina=7
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/?pagina=7
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/?pagina=7
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/?pagina=7
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/?pagina=7
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/?pagina=7
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/?pagina=7
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/?pagina=7
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/?pagina=7
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/?pagina=7
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/?pagina=7
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/?pagina=7
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/?pagina=7
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/?pagina=7
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/?pagina=7
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/?pagina=7
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/?pagina=7
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/?pagina=7
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/?pagina=7
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/?pagina=7
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/?pagina=7
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/?pagina=7
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/?pagina=7
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/?pagina=7
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/?pagina=7
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/?pagina=7
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/?pagina=7
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/?pagina=7
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/?pagina=7
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/?pagina=7
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/?pagina=7
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/?pagina=7
# Coletando URL: https://www.vivareal.com.br/aluguel/sp/sao-paulo/?pagina=7

# %%
# Visualização de valores de aluguél, quarto e endereço

df2=pd.concat(df_lista)
df2.head(104)
# Out:
#                  aluguel          quartos  ...           vaga          area
# 0        R$ 3.300 /Mês       1   Quarto    ...     1   Vaga       34   m²
# 1        R$ 1.950 /Mês      2   Quartos    ...     1   Vaga       50   m²
# 2          R$ 500 /Mês       1   Quarto    ...    --   Vaga       30   m²
# 3        R$ 4.350 /Mês      2   Quartos    ...     1   Vaga       60   m²
# 4        R$ 1.600 /Mês       1   Quarto    ...    --   Vaga       55   m²
# ..                   ...              ...  ...            ...           ...
# 27       R$ 1.200 /Mês      --   Quarto    ...    --   Vaga        7   m²
# 28       R$ 1.900 /Mês       1   Quarto    ...    --   Vaga       45   m²
# 29     R$ 115.440 /Mês      --   Quarto    ...    --   Vaga      900   m²
# 30       R$ 4.500 /Mês      3   Quartos    ...     1   Vaga      103   m²
# 31       R$ 6.000 /Mês      --   Quarto    ...    4   Vagas      160   m²
#
# [104 rows x 6 columns]

# %%
# Quantidade dos dados acima apresentadas

df2.shape
# Out:
# (1800, 6)

# %%
# Amostragem das ruas

df2.endereco.unique()
# Out:
# array(['Rua Fernão Dias, 407 - Pinheiros, São Paulo - SP',
#        'Rua da Consolação, 1131 - Consolação, São Paulo - SP',
#        'Rua Indiana, 1165 - Brooklin, São Paulo - SP',
#        'Rua Cunha Gago, 181 - Pinheiros, São Paulo - SP',
#        'Rua Marapuama, 181 - Alto da Lapa, São Paulo - SP',
#        'Avenida Chibarás, 74 - Moema, São Paulo - SP',
#        'Rua Joaquim Guarani, 485 - Jardim das Acacias, São Paulo - SP',
#        'Rua Dona Eponina Afonseca, 654 - Granja Julieta, São Paulo - SP',
#        'Avenida Engenheiro Armando de Arruda Pereira, 1600 - Jabaquara, São Paulo - SP',
#        'Avenida Marechal Mário Guedes, 40 - Jaguaré, São Paulo - SP',
#        'Rua Major Sertório, 321 - Centro, São Paulo - SP',
#        'Avenida Jurema, 80 - Moema, São Paulo - SP',
#        'Rua Fidélis Papini, 786 - Vila Prudente, São Paulo - SP',
#        'Avenida Ibirapuera, 2120 - Moema, São Paulo - SP',
#        'Rua Tabapuã - Itaim Bibi, São Paulo - SP',
#        'Rua Santa Elvira, 244 - Tatuapé, São Paulo - SP',
#        'Alameda Itu, 859 - Jardim Paulista, São Paulo - SP',
#        'Rua Pais Leme, 136 - Pinheiros, São Paulo - SP',
#        'Rua Soldado João Rodrigues, 112 - Jardim Japão, São Paulo - SP',
#        'Rua Joaquim Antunes, 767 - Pinheiros, São Paulo - SP',
#        'Rua Tutóia, 484 - Vila Mariana, São Paulo - SP',
#        'Rua Bandeira Paulista, 766 - Itaim Bibi, São Paulo - SP',
#        'Rua Haddock Lobo, 1327 - Jardim Paulista, São Paulo - SP',
#        'Rua João Moura, 2311 - Vila Madalena, São Paulo - SP',
#        'Rua Padre Carvalho, 348 - Pinheiros, São Paulo - SP',
#        'Rua Maestro Cardim, 560 - Bela Vista, São Paulo - SP',
#        'Rua Cônego Vicente Miguel Marino, 29 - Barra Funda, São Paulo - SP',
#        'Rua Cabo Eduardo Alegre, 124 - Sumaré, São Paulo - SP',
#        'Rua Martinico Prado, 128 - Higienópolis, São Paulo - SP',
#        'Avenida Brigadeiro Faria Lima, 1355 - Jardim Paulistano, São Paulo - SP',
#        'Rua Doutor Fadlo Haidar, 165 - Vila Olímpia, São Paulo - SP',
#        'Rua Parapuã, 474 - Freguesia do Ó, São Paulo - SP',
#        'Rua Clodomiro Amazonas, 1422 - Vila Nova Conceição, São Paulo - SP',
#        'Rua Tabapuã, 245 - Itaim Bibi, São Paulo - SP',
#        'Avenida Nossa Senhora do Sabará, 110 - Santo Amaro, São Paulo - SP',
#        'Avenida Pedroso de Morais, 457 - Pinheiros, São Paulo - SP'],
#       dtype=object)

# %%
# Amostragem das informações que estão no banco de dados dos imóveis a ser confirmado

df2.head()
# Out:
#               aluguel          quartos  ...           vaga         area
# 0     R$ 3.300 /Mês       1   Quarto    ...     1   Vaga      34   m²
# 1     R$ 1.950 /Mês      2   Quartos    ...     1   Vaga      50   m²
# 2       R$ 500 /Mês       1   Quarto    ...    --   Vaga      30   m²
# 3     R$ 4.350 /Mês      2   Quartos    ...     1   Vaga      60   m²
# 4     R$ 1.600 /Mês       1   Quarto    ...    --   Vaga      55   m²
#
# [5 rows x 6 columns]

# %%
# Alterando nomes e retirando acentos

df2['bairro'] = df2.endereco.str.split('\s-').str[0]
df2['rua'] = df2.endereco.str.split('\s-').str[0]
df2['bairro'] = df2.bairro.str.split(',').str[0]
df2['aluguel'] = df2.aluguel.str.split('/').str[0]
df2['aluguel'] = df2.aluguel.str.split('Mês').str[0]
df2['quartos'] = df2.quartos.str.split('Quartos').str[0]
df2['quartos'] = df2.quartos.str.split('Quarto').str[0]
df2['banheiro'] = df2.banheiro.str.split('Banheiros').str[0]
df2['banheiro'] = df2.banheiro.str.split('Banheiro').str[0]
df2['vaga'] = df2.vaga.str.split('Vagas').str[0]
df2['vaga'] = df2.vaga.str.split('Vaga').str[0]
df2['area'] = df2.area.str.split('m²').str[0]
df2.head()
# Out:
#         aluguel quartos  ...             bairro                      rua
# 0     R$ 3.300     1     ...    Rua Fernão Dias     Rua Fernão Dias, 407
# 1     R$ 1.950     2     ...  Rua da Consolação  Rua da Consolação, 1131
# 2       R$ 500     1     ...        Rua Indiana        Rua Indiana, 1165
# 3     R$ 4.350     2     ...     Rua Cunha Gago      Rua Cunha Gago, 181
# 4     R$ 1.600     1     ...      Rua Marapuama       Rua Marapuama, 181
#
# [5 rows x 8 columns]

# %%
df2['aluguel'] = df2['aluguel'].map(lambda x: x.lstrip('R$ ').rstrip(''))
df2['quartos'] = df2['quartos'].map(lambda x: x.lstrip('-- ').rstrip('"'))
df2['vaga'] = df2['vaga'].map(lambda x: x.lstrip('-- ').rstrip(''))

# %%
# Quantidade dos dados acima apresentadas

df2.shape
# Out:
# (1800, 8)

# %%
# Amostragem

df2.quartos.unique()
# Out:
# array(['1   ', '2   ', '4   ', '', '3   '], dtype=object)

# %%
# Amostragem das informações que estão no banco de dados dos imóveis a ser confirmado

df2.head()
# Out:
#   aluguel quartos  ...             bairro                      rua
# 0  3.300     1     ...    Rua Fernão Dias     Rua Fernão Dias, 407
# 1  1.950     2     ...  Rua da Consolação  Rua da Consolação, 1131
# 2    500     1     ...        Rua Indiana        Rua Indiana, 1165
# 3  4.350     2     ...     Rua Cunha Gago      Rua Cunha Gago, 181
# 4  1.600     1     ...      Rua Marapuama       Rua Marapuama, 181
#
# [5 rows x 8 columns]

# %%
# Gerando o banco de dados dos imóveis solicitados

df2.to_csv('banco_imoveis.csv')

# %%
imoveis = pd.read_csv("banco_imoveis.csv")

# %%
imoveis.head()
# Out:
#    Unnamed: 0  aluguel  ...             bairro                      rua
# 0           0     3.30  ...    Rua Fernão Dias     Rua Fernão Dias, 407
# 1           1     1.95  ...  Rua da Consolação  Rua da Consolação, 1131
# 2           2   500.00  ...        Rua Indiana        Rua Indiana, 1165
# 3           3     4.35  ...     Rua Cunha Gago      Rua Cunha Gago, 181
# 4           4     1.60  ...      Rua Marapuama       Rua Marapuama, 181
#
# [5 rows x 9 columns]

# %%
# Retirando colunas desnecessárias
imoveis = imoveis.drop(columns=['Unnamed: 0'])
imoveis.head()
# Out:
#    aluguel  quartos  ...             bairro                      rua
# 0     3.30      1.0  ...    Rua Fernão Dias     Rua Fernão Dias, 407
# 1     1.95      2.0  ...  Rua da Consolação  Rua da Consolação, 1131
# 2   500.00      1.0  ...        Rua Indiana        Rua Indiana, 1165
# 3     4.35      2.0  ...     Rua Cunha Gago      Rua Cunha Gago, 181
# 4     1.60      1.0  ...      Rua Marapuama       Rua Marapuama, 181
#
# [5 rows x 8 columns]

# %%
imoveis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   aluguel   1800 non-null   float64
#  1   quartos   1200 non-null   float64
#  2   endereco  1800 non-null   object
#  3   banheiro  1800 non-null   int64
#  4   vaga      1250 non-null   float64
#  5   area      1800 non-null   int64
#  6   bairro    1800 non-null   object
#  7   rua       1800 non-null   object
# dtypes: float64(3), int64(2), object(3)
# memory usage: 112.6+ KB

# %%
# Estatística descritiva

imoveis.describe().T
# Out:
#            count        mean         std  min   25%    50%     75%    max
# aluguel   1800.0   50.359167  151.537707  1.0   1.9   3.45    6.25  750.0
# quartos   1200.0    1.833333    1.027831  1.0   1.0   1.50    2.00    4.0
# banheiro  1800.0    1.944444    1.104452  1.0   1.0   2.00    2.00    6.0
# vaga      1250.0    1.760000    1.305283  1.0   1.0   1.00    2.00    5.0
# area      1800.0  104.083333  151.365909  7.0  36.5  54.50  100.75  900.0

# %%
imoveis[['aluguel', 'area']]
# Out:
#       aluguel  area
# 0        3.30    34
# 1        1.95    50
# 2      500.00    30
# 3        4.35    60
# 4        1.60    55
# ...       ...   ...
# 1795     6.00   160
# 1796     1.40    35
# 1797     8.80   210
# 1798    19.00   270
# 1799     7.00    95
#
# [1800 rows x 2 columns]

# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (1.19.5)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
plt.style.use("ggplot")
plt.figure(figsize = (20, 12))
imoveis["aluguel"].hist(bins = 40, ec = "k", alpha = .6, color = "blue")
plt.title("Gráfico")
plt.xlabel("area")
plt.ylabel("aluguel")
# Out:
# Text(0, 0.5, 'aluguel')

# %%
imoveis['area'].values
# Out:
# array([ 34,  50,  30, ..., 210, 270,  95])

# %%
plt.figure(figsize = (20, 12))
plt.plot(imoveis['area'].values);

# %%
# Transformar a coluna de listas em células separadas e converter em números reais em vez de strings

imoveis = imoveis.explode('area')
imoveis['area'] = imoveis['area'].astype('float')

# %%
# O que influencia o aumento dos aluguéis?

plt.figure(figsize=(15, 5))
sns.barplot(x='aluguel', y='area', data=imoveis, hue='quartos');

# %%
plt.figure(figsize=(15, 5))
sns.barplot(y='area', x='aluguel', data=imoveis[:20], hue='quartos');

# %% [markdown]
# ***Dois dormitórios são os mais presentes na busca de uma imóvel para alugar. E quanto maior a área do imóvel, maios o valor do aluguél.***

# %%
plt.figure(figsize=(15, 5))
sns.barplot(y='area', x='aluguel', data=imoveis[:20], hue='quartos');

# %%
# Histograma

sns.histplot(data=imoveis);

# %%
# Transformação logaritmica

sns.histplot(data=imoveis, x='quartos', kde=True);

# %%
sns.histplot(data=imoveis, x='area', kde=True);

# %%
plt.figure(figsize=(15, 5))
sns.histplot(data=imoveis, x='aluguel', kde=True);

# %%
sns.boxplot(data=imoveis);

# %%
sns.boxplot(data=imoveis['area'], orient='h');

# %%
# Excluindo valores NaN

#imoveis.dropna(inplace=True)

# %%
# Verificando a efetivação da exclusão

#imoveis.isnull().sum()

# %%
plt.figure(figsize=(15, 5))
sns.boxplot(data=imoveis['aluguel'], orient='h');

# %%
sns.boxplot(data=imoveis['quartos'], orient='h');

# %%
sns.pairplot(data=imoveis, kind='reg');

# %%
sns.pairplot(data=imoveis, hue='aluguel', kind='reg');
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
# Correlação

correlacao_p = imoveis.corr()

# %%
sns.heatmap(correlacao_p, annot=True);

# %%
correlacao_s = imoveis.corr(method='spearman')

# %%
sns.heatmap(correlacao_s, annot=True);
